# %%
# import hierarchical clustering libraries
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sn

# %%
Univ = pd.read_csv("Universities.csv")

# %%
Univ.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Z Score function 
def std_func(i):
    x = (i-i.mean())/(i.std())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(Univ.iloc[:,1:])
df_norm.head()
# Out:
#         SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0  0.743902  0.847222  0.105263  0.368421  0.255144  0.900000
# 1  1.000000  1.000000  0.144737  0.000000  1.000000  0.466667
# 2  0.621951  0.472222  0.592105  0.157895  0.297461  0.166667
# 3  0.743902  0.666667  0.131579  0.315789  0.415629  0.700000
# 4  0.670732  0.763889  0.250000  0.368421  0.239835  0.766667

# %%
# Normalized data frame (considering the numerical part of data)
df_norm1 = std_func(Univ.iloc[:,1:])
df_norm1.head()
# Out:
#         SAT     Top10    Accept   SFRatio  Expenses  GradRate
# 0  0.401994  0.644235 -0.871888  0.068841 -0.324717  0.803729
# 1  1.370988  1.210256 -0.719814 -1.652182  2.508651 -0.631501
# 2 -0.059432 -0.745090  1.003685 -0.914600 -0.163745 -1.625123
# 3  0.401994 -0.024699 -0.770506 -0.177019  0.285756  0.141315
# 4  0.125139  0.335496 -0.314285  0.068841 -0.382949  0.362120

# %%
# create dendrogram Single
dendrogram = sch.dendrogram(sch.linkage(df_norm1, method='single'))

# %%
# create dendrogram complete
dendrogram1 = sch.dendrogram(sch.linkage(df_norm1, method='complete'))

# %%
# create dendrogram average
dendrogram2 = sch.dendrogram(sch.linkage(df_norm1, method='average'))

# %%
# create dendrogram centroid
dendrogram3= sch.dendrogram(sch.linkage(df_norm1, method='centroid'))

# %%
# create clusters
hc = AgglomerativeClustering(n_clusters=3, affinity = 'euclidean', linkage = 'complete')

# %%
# save clusters for chart
y_hc = hc.fit_predict(df_norm1)
Clusters=pd.DataFrame(y_hc,columns=['Clusters'])
Clusters
# Out:
#     Clusters
# 0          2
# 1          1
# 2          0
# 3          2
# 4          2
# 5          1
# 6          1
# 7          2
# 8          1
# 9          1
# 10         1
# 11         2
# 12         2
# 13         0
# 14         1
# 15         0
# 16         1
# 17         0
# 18         2
# 19         2
# 20         0
# 21         2
# 22         2
# 23         0
# 24         1

# %%
df_norm1['h_clusterid'] =pd.Series(y_hc)

# %%
Univ['h_clusterid']=pd.Series(y_hc)

# %%
Univ
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  \
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
result=Univ.iloc[:,1:].groupby(Univ.h_clusterid).mean()

# %%
result
# Out:
#                      SAT      Top10     Accept    SFRatio      Expenses  \
# h_clusterid
# 0            1114.333333  47.000000  67.833333  17.000000  13384.666667
# 1            1362.777778  90.555556  24.333333   9.666667  41176.888889
# 2            1271.000000  81.500000  35.400000  12.900000  23380.000000
#
#               GradRate  h_clusterid
# h_clusterid
# 0            74.000000            0
# 1            92.222222            1
# 2            89.400000            2
